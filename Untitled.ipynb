# %%
# !ls -lh 009
# Out:
# -rw-r--r--@ 1 steve  staff   255K 23 Nov 22:22 009

# %%
import iris
import matplotlib.pyplot as plt
import iris.quickplot as qplt
import cartopy.crs as ccrs

# %%
c = iris.load_cube('vis')

# %%
ax=plt.axes(projection=ccrs.Robinson())
qplt.pcolormesh(c, cmap='gray')
ax.gridlines()
plt.show()
